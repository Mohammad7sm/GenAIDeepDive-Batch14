# %%
from langchain_ollama import ChatOllama

# %%
llm = ChatOllama(model="llama3.2:latest")

# %%
response = llm.invoke("What is the temprature of Pune currently?")

# %%
print(response.content)
# Out:
# I'm a large language model, I don't have real-time access to current weather conditions or temperatures. However, I can suggest some ways for you to find out the current temperature in Pune:
#
# 1. Check online weather websites: You can check websites like AccuWeather, Weather.com, or India Meteorological Department (IMD) for the current temperature in Pune.
# 2. Use a mobile app: Download a weather app on your smartphone, such as Dark Sky or Weather Underground, which can provide you with real-time weather updates, including temperature.
# 3. Check social media: You can also check social media platforms like Twitter or Facebook for updates from local weather services or news outlets.
#
# Please note that the availability of real-time data may vary depending on your location and internet connectivity.
#
# If you want to get an estimate of the current temperature in Pune, I can suggest some general temperature ranges based on the time of year:
#
# ...
